# %% [markdown]
# # Density and KDE Plots

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
my_df = pd.DataFrame(randn(500,4),columns=['One','Two','Three','Four'])
my_df
# Out:
#           One       Two     Three      Four
# 0    0.898173 -0.333325  1.155164 -0.262942
# 1    0.828104 -0.156934 -0.616484  0.247685
# 2    1.426189 -0.692921  0.780858 -0.540197
# 3    0.244618 -0.642798 -0.356607  0.169279
# 4   -0.668761  0.122433  1.206306  0.107969
# ..        ...       ...       ...       ...
# 495  0.553213  1.952168 -0.660577  0.004193
# 496  0.032390  0.280600  0.807694 -0.698639
# 497 -0.604136 -0.147267 -1.251565 -0.948527
# 498  1.909072  0.697562  1.640598  0.142223
# 499 -1.029499 -0.555998  0.400968  2.800033
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.kde(alpha=0.4,lw=2,grid=True,title="KDE")
# Out:
# <Axes: title={'center': 'KDE'}, ylabel='Density'>
