# %% [markdown]
# # Scatter Plot

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
my_df = pd.DataFrame(randn(500,4),columns=['One','Two','Three','Four'])
my_df
# Out:
#           One       Two     Three      Four
# 0    0.219803 -0.650006 -0.519043  0.866350
# 1   -0.123472 -0.202660 -0.180064  0.070730
# 2   -0.080062 -0.284646 -0.446575 -0.825466
# 3    0.078538  0.509988 -0.405520  1.361901
# 4    0.007276 -0.015548 -1.691439  1.407009
# ..        ...       ...       ...       ...
# 495  0.549166  0.344627 -0.452131  0.651718
# 496 -1.574089  0.939690  1.002159  0.362380
# 497 -0.611473  2.732211 -1.495459 -0.829983
# 498  2.094471  0.680587 -0.207949 -0.598582
# 499 -1.758748  0.059271  0.707371  0.735767
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='scatter',x='One',y='Four',c='Two')
# Out:
# <Axes: xlabel='One', ylabel='Four'>

# %%
my_df.plot(kind='scatter',x='One',y='Four',c='Two',cmap='plasma')
# Out:
# <Axes: xlabel='One', ylabel='Four'>

# %%
my_df.plot(kind='scatter',x='One',y='Four',s=my_df['Two']*100)
# Out:
# c:\Users\aniru\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='One', ylabel='Four'>

# %%
my_df.plot(kind='scatter',x='One',y='Four',s=my_df['Two']*100,alpha=0.4)
# Out:
# c:\Users\aniru\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='One', ylabel='Four'>

# %%
my_df.plot(kind='scatter',x='One',y='Four',s=my_df['Two']*100,alpha=0.4,title="Scatter Plot")
# Out:
# c:\Users\aniru\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: title={'center': 'Scatter Plot'}, xlabel='One', ylabel='Four'>

# %%
my_df.plot.scatter(x='One',y='Two')
# Out:
# <Axes: xlabel='One', ylabel='Two'>
