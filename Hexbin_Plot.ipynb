# %% [markdown]
# # Haxbin Plot

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
my_df = pd.DataFrame(randn(500,4),columns=['One','Two','Three','Four'])
my_df
# Out:
#           One       Two     Three      Four
# 0    0.169284 -1.770150 -0.195624  2.615149
# 1    0.183006  2.151098  0.397374 -0.572689
# 2    1.448234  0.445032  0.773445  1.196718
# 3    0.295539  0.365757 -0.535633 -0.370449
# 4    0.230814 -0.896543 -1.809408  0.576475
# ..        ...       ...       ...       ...
# 495  0.513136 -1.078307 -0.386384 -0.291682
# 496 -0.427447  1.289420 -0.114181 -0.553794
# 497 -1.252000 -1.654769 -1.400691  0.260185
# 498  0.830291  0.357788  0.369752 -0.931083
# 499  1.207534 -0.510480  0.936577  0.514310
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='hexbin',x="One",y='Two')
# Out:
# <Axes: xlabel='One', ylabel='Two'>

# %%
my_df.plot(kind='hexbin',x="One",y='Two',gridsize=20)
# Out:
# <Axes: xlabel='One', ylabel='Two'>

# %%
my_df.plot(kind='hexbin',x="One",y='Two',gridsize=10,colormap='Wistia')
# Out:
# <Axes: xlabel='One', ylabel='Two'>

# %%
my_df.plot.hexbin(x='One',y='Two',C='Three',gridsize=10)
# Out:
# <Axes: xlabel='One', ylabel='Two'>

# %%
my_df.plot.hexbin(x='One',y='Two',C='Three',gridsize=10,title='Hexbin Plot')
# Out:
# <Axes: title={'center': 'Hexbin Plot'}, xlabel='One', ylabel='Two'>

# %%
my_df.plot.hexbin(x='One',y='Two',C='Three',gridsize=10,title='Hexbin Plot',grid=True)
# Out:
# <Axes: title={'center': 'Hexbin Plot'}, xlabel='One', ylabel='Two'>
