# %% [markdown]
# # Histogram

# %%
import pandas as pd
import numpy as np
from numpy.random import rand
# %matplotlib inline

# %%
my_df = pd.DataFrame(rand(100,4),columns=['One','Two','Three','Four'])
my_df
# Out:
#          One       Two     Three      Four
# 0   0.768312  0.227335  0.983605  0.570170
# 1   0.104100  0.375498  0.261989  0.429147
# 2   0.902716  0.979319  0.851157  0.328874
# 3   0.204764  0.132354  0.996722  0.252595
# 4   0.723417  0.526658  0.304087  0.710012
# ..       ...       ...       ...       ...
# 95  0.073320  0.205139  0.275080  0.283471
# 96  0.947640  0.183825  0.074305  0.759292
# 97  0.200898  0.105693  0.685836  0.375245
# 98  0.414157  0.596041  0.731325  0.424152
# 99  0.196122  0.452897  0.180472  0.681801
#
# [100 rows x 4 columns]

# %%
my_df['Three'].hist()
# Out:
# <Axes: >

# %%
my_df['Three'].hist(bins=20)
# Out:
# <Axes: >

# %%
my_df['Three'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df['Three'].hist(bins=20,grid=False,legend=True)
# Out:
# <Axes: >
