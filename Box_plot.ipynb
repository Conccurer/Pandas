# %% [markdown]
# # Box Plot

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
my_df = pd.DataFrame(randn(500,4),columns=['One','Two','Three','Four'])
my_df
# Out:
#           One       Two     Three      Four
# 0   -1.709342  0.503400  2.745555  0.286318
# 1    0.149858 -1.681351  0.478273 -0.678095
# 2   -0.372715  0.988425 -0.432811  2.983824
# 3    0.611944 -0.478665 -0.444928  0.687470
# 4    1.051896 -1.462247  1.473981  1.072358
# ..        ...       ...       ...       ...
# 495  0.446730 -0.934449  0.783183 -0.128390
# 496 -0.292818 -1.299237 -0.195042 -0.109394
# 497 -0.460835  2.896351  0.194265  0.576213
# 498  0.114180 -1.016643 -0.472623 -1.357275
# 499 -1.597543  0.855900  0.097133 -1.145002
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='box')
# Out:
# <Axes: >

# %%
my_df.plot(kind='box',figsize=(10,5))
# Out:
# <Axes: >

# %%
my_df.plot(kind='box',colormap='plasma')
# Out:
# <Axes: >

# %%
my_df.plot(kind='box',title='Box Plot')
# Out:
# <Axes: title={'center': 'Box Plot'}>

# %%
my_df.plot.box(title="Box plot")
# Out:
# <Axes: title={'center': 'Box plot'}>

# %%
my_df.plot(kind='box',grid=True)
# Out:
# <Axes: >
